# %% [markdown]
# # About Data
#
# The dataset for this project originates from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Census+Income). The datset was donated by Ron Kohavi and Barry Becker, after being published in the article _"Scaling Up the Accuracy of Naive-Bayes Classifiers: A Decision-Tree Hybrid"_. You can find the article by Ron Kohavi [online](https://www.aaai.org/Papers/KDD/1996/KDD96-033.pdf). The data was collected from the 1994 U.S. Census. The data we investigate here consists of small changes to the original dataset, such as removing the `'fnlwgt'` feature and records with missing or ill-formatted entries.
#
#
# ** Featureset Exploration **
#
# * **age**: continuous.
# * **workclass**: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * **fnlwgt**: continuous.
# * **education**: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * **education-num**: continuous.
# * **marital-status**: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * **occupation**: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * **relationship**: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * **race**: Black, White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other.
# * **sex**: Female, Male.
# * **capital-gain**: continuous.
# * **capital-loss**: continuous.
# * **hours-per-week**: continuous.
# * **native-country**: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# ###### Gathering data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score

# %%
df=pd.read_csv('adult.data',sep=',',names=['age',
 'workclass',
 'fnlwgt',
 'education_level',
 'education_num',
 'marital_status',
 'occupation',
 'relationship',
 'race',
 'sex',
 'capital_gain',
 'capital_loss',
 'hours_per_week',
 'native_country',
 'income'])

# %%
df.sample(5)
# Out:
#        age      workclass  fnlwgt education_level  education_num  \
# 24149   21              ?  140012    Some-college             10
# 28659   36      State-gov   98037       Assoc-voc             11
# 28803   45   Self-emp-inc  117605         HS-grad              9
# 3623    31        Private  247328             9th              5
# 6835    39      Local-gov  178100         Masters             14
#
#             marital_status          occupation relationship  \
# 24149        Never-married                   ?    Own-child
# 28659   Married-civ-spouse       Other-service      Husband
# 28803   Married-civ-spouse     Exec-managerial      Husband
# 3623    Married-civ-spouse   Machine-op-inspct      Husband
# 6835              Divorced      Prof-specialty    Unmarried
#
#                       race      sex  capital_gain  capital_loss  \
# 24149                White     Male             0             0
# 28659   Asian-Pac-Islander     Male             0             0
# 28803                White     Male             0             0
# 3623                 White     Male          3137             0
# 6835                 White   Female             0             0
#
#        hours_per_week  native_country  income
# 24149              20   United-States   <=50K
# 28659              40   United-States   <=50K
# 28803              48   United-States    >50K
# 3623               40          Mexico   <=50K
# 6835               40   United-States   <=50K

# %% [markdown]
# ###### Assessing data

# %%
# strip all object elements before clean
df[list(df.select_dtypes(['object']))]=df.select_dtypes(['object']).applymap(lambda x: x.strip())

# %%
# Nan 
df.isna().sum().sum()
# Out:
# 0

# %%
# missing values
df[df.values=='?']
# Out:
#        age workclass  fnlwgt education_level  education_num  \
# 14      40   Private  121772       Assoc-voc             11
# 27      54         ?  180211    Some-college             10
# 27      54         ?  180211    Some-college             10
# 38      31   Private   84154    Some-college             10
# 51      18   Private  226956         HS-grad              9
# ...    ...       ...     ...             ...            ...
# 32539   71         ?  287372       Doctorate             16
# 32541   41         ?  202822         HS-grad              9
# 32541   41         ?  202822         HS-grad              9
# 32542   72         ?  129912         HS-grad              9
# 32542   72         ?  129912         HS-grad              9
#
#            marital_status     occupation   relationship                race  \
# 14     Married-civ-spouse   Craft-repair        Husband  Asian-Pac-Islander
# 27     Married-civ-spouse              ?        Husband  Asian-Pac-Islander
# 27     Married-civ-spouse              ?        Husband  Asian-Pac-Islander
# 38     Married-civ-spouse          Sales        Husband               White
# 51          Never-married  Other-service      Own-child               White
# ...                   ...            ...            ...                 ...
# 32539  Married-civ-spouse              ?        Husband               White
# 32541           Separated              ?  Not-in-family               Black
# 32541           Separated              ?  Not-in-family               Black
# 32542  Married-civ-spouse              ?        Husband               White
# 32542  Married-civ-spouse              ?        Husband               White
#
#           sex  capital_gain  capital_loss  hours_per_week native_country  \
# 14       Male             0             0              40              ?
# 27       Male             0             0              60          South
# 27       Male             0             0              60          South
# 38       Male             0             0              38              ?
# 51     Female             0             0              30              ?
# ...       ...           ...           ...             ...            ...
# 32539    Male             0             0              10  United-States
# 32541  Female             0             0              32  United-States
# 32541  Female             0             0              32  United-States
# 32542    Male             0             0              25  United-States
# 32542    Male             0             0              25  United-States
#
#       income
# 14      >50K
# 27      >50K
# 27      >50K
# 38      >50K
# 51     <=50K
# ...      ...
# 32539   >50K
# 32541  <=50K
# 32541  <=50K
# 32542  <=50K
# 32542  <=50K
#
# [4262 rows x 15 columns]

# %%
# replace nan back
df.replace('?',np.nan,inplace=True)

# %%
# nans
df.isna().sum()
# Out:
# age                   0
# workclass          1836
# fnlwgt                0
# education_level       0
# education_num         0
# marital_status        0
# occupation         1843
# relationship          0
# race                  0
# sex                   0
# capital_gain          0
# capital_loss          0
# hours_per_week        0
# native_country      583
# income                0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 4262

# %% [markdown]
# > there are total 4262 nans

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1   workclass        30725 non-null  object
#  2   fnlwgt           32561 non-null  int64
#  3   education_level  32561 non-null  object
#  4   education_num    32561 non-null  int64
#  5   marital_status   32561 non-null  object
#  6   occupation       30718 non-null  object
#  7   relationship     32561 non-null  object
#  8   race             32561 non-null  object
#  9   sex              32561 non-null  object
#  10  capital_gain     32561 non-null  int64
#  11  capital_loss     32561 non-null  int64
#  12  hours_per_week   32561 non-null  int64
#  13  native_country   31978 non-null  object
#  14  income           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# > all the data types are correct

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# duplivcates
df[df.duplicated()].shape
# Out:
# (24, 15)

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

# %%
# correlation heatmap
sns.heatmap(df.corr(),annot=True);

# %%
sns.pairplot(df, corner=True,kind='reg');

# %% [markdown]
# ###### Data Wrangling
